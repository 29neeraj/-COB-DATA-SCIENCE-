# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\Asus\Downloads\dataset - netflix1.csv")
df
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 686.8+ KB

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
df.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
df['duration'] = df['duration'].replace('[^0-9]', '', regex=True)
df['duration'] = pd.to_numeric(df['duration'], errors='coerce')
print(df)
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating  duration  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.boxplot(x=df['release_year'], color='skyblue')
plt.title('Box Plot of Release Year')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df['is_movie'] = df['type'] == 'Movie'
df.loc[df['is_movie'], 'duration'] = df.loc[df['is_movie'], 'duration'].replace(' min', '', regex=True).astype(float)
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.boxplot(x='type', y='release_year', data=df)
plt.title('Box Plot of Release Year')
plt.tight_layout()
plt.show()

# %%
df['is_movie'] = df['type'] == 'Movie'
df.loc[df['is_movie'], 'duration'] = df.loc[df['is_movie'], 'duration'].replace(' min', '', regex=True).astype(float)
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(x='type', y='release_year', data=df)
plt.title('Box Plot of Release Year')
plt.tight_layout()
plt.show()

# %%
df['is_movie'] = df['type'] == 'Movie'
df.loc[df['is_movie'], 'duration'] = df.loc[df['is_movie'], 'duration'].replace(' min', '', regex=True).astype(float)
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.scatterplot(x='type', y='release_year', data=df)
plt.title('Box Plot of Release Year')
plt.tight_layout()
plt.show()

# %%
df['is_movie'] = df['type'] == 'Movie'
df.loc[df['is_movie'], 'duration'] = df.loc[df['is_movie'], 'duration'].replace(' min', '', regex=True).astype(float)
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.barplot(x='type', y='release_year', data=df)
plt.title('Box Plot of Release Year')
plt.tight_layout()
plt.show()

# %%
df.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13        90
# 1         France  9/24/2021          2021  TV-MA         1
# 2  United States  9/24/2021          2021  TV-MA         1
# 3         Brazil  9/22/2021          2021  TV-PG        91
# 4  United States  9/24/2021          1993  TV-MA       125
#
#                                            listed_in  is_movie
# 0                                      Documentaries      True
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df['is_movie'] = df['type'] == 'Movie'

df.loc[df['is_movie'], 'duration'] = df.loc[df['is_movie'], 'duration'].replace(' min', '', regex=True).astype(float)

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
sns.boxplot(x='type', y='release_year', data=df)
plt.title('Box Plot of Release Year')

plt.subplot(1, 2, 2)
sns.boxplot(x='type', y='duration', data=df)
plt.title('Box Plot of Duration (minutes)')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df['duration'] = df['duration'].replace(' min', '', regex=True).astype(int)

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.boxplot(x=df['release_year'], color='skyblue')
plt.title('Box Plot of Release Year')

plt.subplot(1, 2, 2)
sns.boxplot(x=df['duration'], color='salmon')
plt.title('Box Plot of Duration (minutes)')

plt.tight_layout()
plt.show()
